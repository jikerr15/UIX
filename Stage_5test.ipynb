# %% [markdown]
# <a href="https://colab.research.google.com/github/jikerr15/UIX/blob/main/Stage_5test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
file1 = "/content/Task1.csv"
df1 = pd.read_csv(file1)
print(df1)
# Out:
#   Participant  Errors  Clicks  Pauses  Time it took(sec) Task Completed
# 0       Caleb       0       2       0                5.2            yes
# 1         Ian       0       2       0                5.5            yes
# 2       Katie       1       3       1                7.1            yes
# 3        Emma       0       2       2                8.8            yes
# 4      Emmett       1       4       0                8.1            yes

# %%
file2 = "/content/Task2.csv"
df2 = pd.read_csv(file2)
print(df2)
# Out:
#   Participant  Errors  Clicks  Pauses  Time it took(sec) Task Completed
# 0       Caleb       0       3       1               10.3            yes
# 1         Ian       1       4       3               14.8            yes
# 2       Katie       3       9       4               25.6            yes
# 3        Emma       1       4       2               13.2            yes
# 4      Emmett       5      12       6               43.5             no

# %%
file3 = "/content/Task3.csv"
df3 = pd.read_csv(file3)
print(df3)
# Out:
#   Participant  Errors  Clicks  Pauses  Time it took Task Completed
# 0       Caleb       1       6       1          13.3            yes
# 1         Ian       0       5       1          10.7            yes
# 2       Katie       3      10       4          26.3            yes
# 3        Emma       2       8       2          20.4            yes
# 4      Emmett       0       5       2          15.9            yes

# %%
file4 = "/content/Task4.csv"
df4 = pd.read_csv(file4)
print(df4)
# Out:
#   Participant  Errors  Clicks  Pauses  Time it took(sec) Task Completed
# 0       Caleb       0       2       1                5.3            yes
# 1         Ian       0       1       0                2.7            yes
# 2       Katie       1       3       1                6.0            yes
# 3        Emma       0       2       0                4.2            yes
# 4      Emmett       1       3       2                8.3            yes

# %% [markdown]
# Tasks mean calculated through the dataframes of the data colected. With the Calculated means of all of the test qualitys the most important one to look at is the Average time it took to complete. If the average time for the participants goes far beyond the average that it shold be at we most likeley have a usability problem there and it should be invetigated. The average un scientific means for the tasks are Task 1: 6.6sec, Task 2: 9.6sec, Task 3: 8.2sec, and Task 4: 3.4sec

# %%
print("Task 1:")
df1[['Errors','Clicks','Pauses','Time it took(sec)']].mean()
# Out:
# Task 1:
# Errors               0.40
# Clicks               2.60
# Pauses               0.60
# Time it took(sec)    6.94
# dtype: float64

# %%
print("Task 2:")
df2[['Errors','Clicks','Pauses','Time it took(sec)']].mean()
# Out:
# Task 2:
# Errors                2.00
# Clicks                6.40
# Pauses                3.20
# Time it took(sec)    21.48
# dtype: float64

# %%
print("Task 3:")
df3[['Errors','Clicks','Pauses','Time it took']].mean()
# Out:
# Task 3:
# Errors           1.20
# Clicks           6.80
# Pauses           2.00
# Time it took    17.32
# dtype: float64

# %%
print("Task 4:")
df4[['Errors','Clicks','Pauses','Time it took(sec)']].mean()
# Out:
# Task 4:
# Errors               0.4
# Clicks               2.2
# Pauses               0.8
# Time it took(sec)    5.3
# dtype: float64

# %% [markdown]
# Tasks Standard deviation calculated through the dataframes of the collected data

# %%
print("Task 1:")
df1[['Errors','Clicks','Pauses','Time it took(sec)']].std()
# Out:
# Task 1:
# Errors               0.547723
# Clicks               0.894427
# Pauses               0.894427
# Time it took(sec)    1.575754
# dtype: float64

# %% [markdown]
# The Task 1 had the fewest deviation then all of the other tasks which is good for the dashboard and the usability of the app overall becuase it meant people could look at something that they've never seen before and perform the first simple task.

# %%
print("Task 2:")
df2[['Errors','Clicks','Pauses','Time it took(sec)']].std()
# Out:
# Task 2:
# Errors                2.000000
# Clicks                3.911521
# Pauses                1.923538
# Time it took(sec)    13.601728
# dtype: float64

# %% [markdown]
# ON this task there was a high deviation from the mean which makes sense since there was problems with finishing

# %%
print("Task 3:")
df3[['Errors','Clicks','Pauses','Time it took']].std()
# Out:
# Task 3:
# Errors          1.303840
# Clicks          2.167948
# Pauses          1.224745
# Time it took    6.167009
# dtype: float64

# %% [markdown]
# Task 3 was the second most deviant task. As you can see all of the standard deviations are above 1 which means participants were mostly pretty far from the mean

# %%
print("Task 4:")
df4[['Errors','Clicks','Pauses','Time it took(sec)']].std()
# Out:
# Task 4:
# Errors               0.547723
# Clicks               0.836660
# Pauses               0.836660
# Time it took(sec)    2.089258
# dtype: float64

# %% [markdown]
# Task 4 as you can soo in the graph below was on the mark for all of the participants with only a max deviation of 2 secs between people. The graph was basically a straight line across with only slight ammounts of movement.

# %% [markdown]
# Graphical representation

# %% [markdown]
# The bar charts below are just an overview of the four different tasks. And allows us to see where we had different problems for example if there were a lot of errors in a certain task we could see that very easily here. The x axis label is 0-4 of the participants so 0 is Caleb and so on.

# %%
df1[['Errors','Clicks','Pauses','Time it took(sec)']].plot.bar()

# %%
df2[['Errors','Clicks','Pauses','Time it took(sec)']].plot.bar()

# %% [markdown]
# In task 2 there was the only task that was failed by someone durning all of the testing. Everyones comments for this task though was that they couldn't see the button they were looking for. Which can be seen in the graph with the ammount of time taken looking for it and the ammount of clicks trying to figure out where it was.

# %%
df3[['Errors','Clicks','Pauses','Time it took']].plot.bar()

# %% [markdown]
# In Task 3 we can see that almost everyone paused at some point. So that could be considired because that means the path to get to the task was not as clear as we'd hoped. The other thing is that all of the users on this task commented about how it was hard to find where to go off the dashboard and they almost all clicked on the campaingn title which doesn't go anywhere which confused them.

# %%
df4[['Errors','Clicks','Pauses','Time it took(sec)']].plot.bar()

# %%
df1 = df1.sort_values('Time it took(sec)')

# %%
ax = df1.plot(x="Participant", y=["Time it took(sec)"], kind="line", figsize=(9, 8))
ax = df2.plot(x="Participant", y=["Time it took(sec)"], kind="line", figsize=(9, 8), ax=ax)
ax = df4.plot(x="Participant", y=["Time it took(sec)"], kind="line", figsize=(9, 8), ax = ax)
df3.plot(x="Participant", y=["Time it took"], kind="line", figsize=(9, 8), ax=ax)

# %% [markdown]
# The figure above shows a graph of the time it took for each Task to be finished, the blue is Task1, orange is two, red is three and green is 4. Overall it seems like orange was the hardest for most people. Unfortuantely that was also the only task to have a given up failure. Emmett gave up because he couldn't find how to navigate to it. Below is the graphs broken out in to thier seperate parts so you can see them all. So we know there is a problem somewhere in Task 2. All the other times were pretty even the means were pretty central and the standard deviation was low. There were some comments but the statisitics are all around the same.

# %%
df1.plot(x="Participant", y=["Time it took(sec)"], kind="line", figsize=(9, 8))
df2.plot(x="Participant", y=["Time it took(sec)"], kind="line", figsize=(9, 8))
df4.plot(x="Participant", y=["Time it took(sec)"], kind="line", figsize=(9, 8))
df3.plot(x="Participant", y=["Time it took"], kind="line", figsize=(9, 8))
